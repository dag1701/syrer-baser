# %% [markdown]
# # Oppgaver om pH-beregninger - Kjemi 1 og 2
#
# <div class="alert alert-block alert-info">
#     <b>NB!</b> Fordi innstillingene i Skoleplattform Oslo ikke lar oss innstallere pHcalc på noen enkel måte, må vi kjøre dette programmet på en virtuell server eksternt.
# </div>
#
# 1.	Beregn pH i 1 M HCl og 1 M CH3COOH (etansyre/eddiksyre). Hvorfor er det så stor forskjell i pH i de to løsningene?
#
# 2.	Beregn pH i et system som består av 1 M HF og 1 M CHOOH (metansyre/maursyre).
#
# 3.	Beskriv hva programmet nedenfor gjør. Kjør deretter programmet og beskriv plottet.
#
# ![image.jpeg](attachment:image.jpeg)
#
#
#
# 4.	Lag samme type plott som lages i oppgave 1, men med karbonsyre istedenfor fosforsyre. Diskuter likheter og forskjeller i plottene.
#
# 5.	Forklar hva følgende program gjør. Bruk programmet til å simulere en titrering av karbonsyre med NaOH. Hva er forskjellen på de to titreringene?
#
# ![image-2.jpeg](attachment:image-2.jpeg)
#
# Koden kan dere kjøre i cellen under:

# %%
#Kode kjøres i denne cellen!

# %% [markdown]
# __Kilder: Dette opplegget er hentet fra digitale ressurser for Kjemi 1 og Kjemi 2 i Aunivers utgitt av Aschehoug forlag A/S.__
